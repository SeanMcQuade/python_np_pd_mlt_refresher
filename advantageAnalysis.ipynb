# %% [markdown]
# This script will show the probability density function of rolling a d20 with or without advantage.

# %%
import numpy as np
D20_noAdvantage = np.random.rand(2,3)

# %%
D20_noAdvantage
# Out:
# array([[0.74682972, 0.3282613 , 0.30585209],
#        [0.63658542, 0.81523165, 0.23258784]])

# %%
import random
D20_noAdvantage = random.choices(range(20), k=int(1e6))

# %%
N
# Out:
# 1000000.0

# %%
D20_Advantage = np.array([random.choices(range(20), k=int(1e6)), random.choices(range(20), k=int(1e6))])

# %%
print(D20_Advantage.shape)
# Out:
# (2, 1000000)

# %%
test = np.max(D20_Advantage,axis=0)
print(test)
test.shape
# Out:
# [ 5 11 13 ...  2 11  9]
# (1000000,)

# %%
print(D20_Advantage[:2])
# Out:
# [[ 1 11  6 ...  2  1  9]
#  [ 5  5 13 ...  1 11  3]]

# %%
D20_AdvantageMax = max(D20_Advantage)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 D20_AdvantageMax = max(D20_Advantage)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
testmat = [[2,4,6],[5,1,3],[7,8,9]]

# %%
testmat[:2]
# Out:
# [[2, 4, 6], [5, 1, 3]]

# %%
testmat[:2,:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 testmat[:2,:2]
#
# TypeError: list indices must be integers or slices, not tuple
