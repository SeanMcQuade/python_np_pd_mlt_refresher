# %% [markdown]
# This will start my own personal refresher in Python.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [raw]
# Code to check through a list of letter combinations and find complete words

# %%
## First load all possible letters into vectors, a word is one selection from each of 6--8 vectors each vector has 8 elements.

# %%
import numpy as np

RedP_words = ([["l","s","m","w","b","c","p","t"],["e","i","o","u","h","r","t","a"],
               ["n","t","s","o","i","v","l","r"],["t","h","s","i","k","v","a","d"],
               ["n","l","r","c","s","a","e","o"],["r","w","t","e","y","n","d","g"]])

Lost_eyes = ([["f","r","l","h","c","s","v","p"],["a","e","i","o","u","h","l","r"],
               ["r","p","g","a","o","c","m","t"],["s","t","r","d","l","e","i","u"],
               ["e","i","u","t","r","l","h","a"],["e","z","h","l","t","n","r","s"],["r","n","y","s","g","h","d","e"]])

Sin_infinity = ([["h","l","m","n","r","t","d","g"],["a","e","i","o","u","h","r","y"],
               ["f","n","s","o","m","r","a","u"],["i","o","u","p","g","t","a","e"],
               ["n","o","r","s","t","c","g","l"],["i","o","h","n","l","t","a","e"],
               ["t","o","l","u","c","e","d","s"],["y","h","e","s","n","r","k","t"]])

first_string_set = [6] #set for i1 in for loop if you want to s
for i1 in np.arange(3):
    for i2 in np.arange(3):
        for i3 in np.arange(3):
            for i4 in np.arange(3):
                for i5 in np.arange(3):
                    for i6 in np.arange(3):
                        candidateWord = []
                        for i in np.arange(6):
                            letter_indices = [i1,i2,i3,i4,i5,i6]
                            candidateWord.append(RedP_words[i][letter_indices[i]])
                        print(candidateWord[0]+candidateWord[1]+candidateWord[2]+candidateWord[3]+candidateWord[4]+candidateWord[5])
# Out:
# pentnr
# pentnw
# pentnt
# pentlr
# pentlw
# pentlt
# pentrr
# pentrw
# pentrt
# penhnr
# penhnw
# penhnt
# penhlr
# penhlw
# penhlt
# penhrr
# penhrw
# penhrt
# pensnr
# pensnw
# pensnt
# penslr
# penslw
# penslt
# pensrr
# pensrw
# pensrt
# pettnr
# pettnw
# pettnt
# pettlr
# pettlw
# pettlt
# pettrr
# pettrw
# pettrt
# pethnr
# pethnw
# pethnt
# pethlr
# pethlw
# pethlt
# pethrr
# pethrw
# pethrt
# petsnr
# petsnw
# petsnt
# petslr
# petslw
# petslt
# petsrr
# petsrw
# petsrt
# pestnr
# pestnw
# pestnt
# pestlr
# pestlw
# pestlt
# pestrr
# pestrw
# pestrt
# peshnr
# peshnw
# peshnt
# peshlr
# peshlw
# peshlt
# peshrr
# peshrw
# peshrt
# pessnr
# pessnw
# pessnt
# pesslr
# pesslw
# pesslt
# pessrr
# pessrw
# pessrt
# pintnr
# pintnw
# pintnt
# pintlr
# pintlw
# pintlt
# pintrr
# pintrw
# pintrt
# pinhnr
# pinhnw
# pinhnt
# pinhlr
# pinhlw
# pinhlt
# pinhrr
# pinhrw
# pinhrt
# pinsnr
# pinsnw
# pinsnt
# pinslr
# pinslw
# pinslt
# pinsrr
# pinsrw
# pinsrt
# pittnr
# pittnw
# pittnt
# pittlr
# pittlw
# pittlt
# pittrr
# pittrw
# pittrt
# pithnr
# pithnw
# pithnt
# pithlr
# pithlw
# pithlt
# pithrr
# pithrw
# pithrt
# pitsnr
# pitsnw
# pitsnt
# pitslr
# pitslw
# pitslt
# pitsrr
# pitsrw
# pitsrt
# pistnr
# pistnw
# pistnt
# pistlr
# pistlw
# pistlt
# pistrr
# pistrw
# pistrt
# pishnr
# pishnw
# pishnt
# pishlr
# pishlw
# pishlt
# pishrr
# pishrw
# pishrt
# pissnr
# pissnw
# pissnt
# pisslr
# pisslw
# pisslt
# pissrr
# pissrw
# pissrt
# pontnr
# pontnw
# pontnt
# pontlr
# pontlw
# pontlt
# pontrr
# pontrw
# pontrt
# ponhnr
# ponhnw
# ponhnt
# ponhlr
# ponhlw
# ponhlt
# ponhrr
# ponhrw
# ponhrt
# ponsnr
# ponsnw
# ponsnt
# ponslr
# ponslw
# ponslt
# ponsrr
# ponsrw
# ponsrt
# pottnr
# pottnw
# pottnt
# pottlr
# pottlw
# pottlt
# pottrr
# pottrw
# pottrt
# pothnr
# pothnw
# pothnt
# pothlr
# pothlw
# pothlt
# pothrr
# pothrw
# pothrt
# potsnr
# potsnw
# potsnt
# potslr
# potslw
# potslt
# potsrr
# potsrw
# potsrt
# postnr
# postnw
# postnt
# postlr
# postlw
# postlt
# postrr
# postrw
# postrt
# poshnr
# poshnw
# poshnt
# poshlr
# poshlw
# poshlt
# poshrr
# poshrw
# poshrt
# possnr
# possnw
# possnt
# posslr
# posslw
# posslt
# possrr
# possrw
# possrt

# %% [markdown]
# Generate all possible words in readable form.

# %%
import numpy as np
letters = ["P"]
for letter in np.arange(8):
    for word in RedP_words[1:5]:
        letters.append(word[letter])
        print(letters[0],letters[1])
# Out:
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e
# P e

# %%
print(letters)
# Out:
# ['P', 'e', 'n', 't', 'n', 'i', 't', 'h', 'l', 'o', 's', 's', 'r', 'u', 'o', 'i', 'c', 'h', 'i', 'k', 's', 'r', 'v', 'v', 'a', 't', 'l', 'a', 'e', 'a', 'r', 'd', 'o']
